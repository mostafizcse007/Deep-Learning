# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=2,n_samples=100,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,
random_state = 41,hypercube = False,class_sep = 15)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X,y):
    w1=w2=b = 1
    lr = .01

    for j in range(1000):
        for i in range(X.shape[0]):
            z = w1*X[i][0] + w2*X[i][1] + b

            if z*y[i]<0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]

    return w1,w2,b

# %%
w1,w2,b = perceptron(X,y)

# %%
m = -(w1/w2)
c = -(b/w2)

m,c
# Out:
# (np.float64(-2.196853431511779), np.float64(-2.7050281152724827))

# %%
X_fig = np.linspace(-5,5,1000)
y_fig = m*X_fig + c

# %%
plt.figure(figsize=(10,8))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.plot(X_fig,y_fig)
