# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
class MyRNN(nn.Module):
    def __init__(self):
        super(MyRNN,self).__init__()
        self.rnn = nn.RNN(input_size=5,batch_first=True,hidden_size=3)
        self.fc = nn.Linear(3,1)
        self.sigmoid = nn.Sigmoid()

    def forward(self,x):
        out,_ = self.rnn(x)
        out = out[:,-1,:]
        out = self.fc(out)
        out = self.sigmoid(out)
        return out

# %%
model = MyRNN()
