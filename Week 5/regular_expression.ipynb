# %%
import re

# %%
text = '''The morning began quietly, with pale sunlight slipping through the curtains and spreading across the wooden floor. Outside, the streets were still calm, and only the distant sound of passing cars disturbed the silence. A small breeze moved through the trees, shaking loose a few leaves that drifted slowly to the ground. It was the kind of morning that made everything feel possible, even if there was no clear plan for the day.

In a small office near the corner of the room, a notebook lay open beside a cup of coffee. The pages were filled with scattered ideas, half-written sentences, and sketches that seemed important at the time they were drawn. Some notes were practical, while others were only fragments of imagination. There were lists of tasks, names of places, reminders, and questions without answers. Together, they created the feeling of a mind trying to organize itself.

The room itself was simple but comfortable. A wooden desk stood against the wall, covered with books, papers, pens, and a small lamp. A chair with a soft cushion faced the desk, slightly turned as if someone had just left it. On the shelf above, old photographs and small souvenirs collected dust quietly. Each item carried a memory, although not every memory was easy to explain.

As the day continued, the city slowly became louder. People walked along the sidewalks with bags, phones, and hurried expressions. Buses stopped at crowded corners, bicycles passed between cars, and shopkeepers opened their doors. Somewhere nearby, someone was baking bread, and the warm smell traveled through the air. The ordinary rhythm of daily life returned, one sound at a time.

Inside the office, work began slowly. At first, there was only hesitation. The blank screen seemed larger than usual, and the blinking cursor waited patiently. After a few minutes, one sentence appeared, then another. The first sentences were not perfect, but they were enough to begin. Sometimes progress does not arrive as a sudden burst of inspiration. Sometimes it comes quietly, through small decisions repeated again and again.

By midday, the sunlight had moved across the room. The coffee had grown cold, and the notebook had gained several new lines. A few ideas had been crossed out, while others had been circled for later. The work was still unfinished, but it had taken shape. That was enough for the moment. Not every task needs to be completed immediately; some simply need to be started.

In the afternoon, clouds gathered slowly above the buildings. The light became softer, and the air felt cooler. People began moving faster, hoping to reach their destinations before the rain. A dog barked from a balcony, children laughed on their way home from school, and somewhere in the distance, thunder rolled gently. The city seemed to hold its breath for a moment.

Then the rain began. At first, it was only a few drops against the window. Soon, the drops became steady, tapping against the glass like fingers on a table. The street below changed color as the pavement darkened. Umbrellas opened, cars splashed through puddles, and the smell of rain rose from the ground. It was peaceful in a way that only rainy afternoons can be.

The work continued, though more slowly now. Rain has a way of changing the mood of a room. It makes time feel wider and thoughts feel deeper. The same sentence that seemed ordinary in the morning appeared different in the afternoon light. Words were moved, removed, and rewritten. Some paragraphs became shorter, others longer. The goal was not perfection, but clarity.

By evening, the rain had stopped. The clouds began to break apart, revealing a narrow strip of orange sky. Lights appeared in windows across the neighborhood. People returned home, carrying groceries, umbrellas, and tired conversations. The day was ending, but it did not feel wasted. Even small progress has value when it is honest and steady.

The notebook was finally closed, and the screen went dark. The room became quiet again, just as it had been in the morning. But something had changed. A few thoughts had become words, and a few words had become paragraphs. It was not a grand achievement, but it was real. And sometimes, that is enough.'''

# %%
pattern = r"[a-z]+ing"

# %%
ans = re.finditer(pattern,text)

# %%
ans

# %%
for text in ans:
    print(text[0])
# Out:
# morning
# slipping
# spreading
# passing
# shaking
# morning
# everything
# feeling
# trying
# baking
# blinking
# building
# moving
# hoping
# tapping
# fing
# changing
# morning
# evening
# revealing
# carrying
# ending
# morning
# something

# %%
ans2 = re.findall(pattern,text)

# %%
ans2
# Out:
# ['morning',
#  'slipping',
#  'spreading',
#  'passing',
#  'shaking',
#  'morning',
#  'everything',
#  'feeling',
#  'trying',
#  'baking',
#  'blinking',
#  'building',
#  'moving',
#  'hoping',
#  'tapping',
#  'fing',
#  'changing',
#  'morning',
#  'evening',
#  'revealing',
#  'carrying',
#  'ending',
#  'morning',
#  'something']

# %%
text = "Phone number: 01309-462705"
new_text = re.sub(r"\d",'*',text)

# %%
new_text
# Out:
# 'Phone number: *****-******'
